# %% [markdown]
# # Exploring Covid-19 Data

# %%
from covid import Covid

# %%
covid=Covid(source='worldometers')

# %%
data=covid.get_data()
data
# Out:
# [{'country': 'North America',
#   'confirmed': 786960,
#   'new_cases': 27205,
#   'deaths': 41286,
#   'recovered': 81259,
#   'active': 664415,
#   'critical': 14655,
#   'new_deaths': 1864,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('0'),
#   'total_deaths_per_million': Decimal('0')},
#  {'country': 'Europe',
#   'confirmed': 1056795,
#   'new_cases': 27581,
#   'deaths': 99190,
#   'recovered': 298699,
#   'active': 658906,
#   'critical': 26386,
#   'new_deaths': 2962,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('0'),
#   'total_deaths_per_million': Decimal('0')},
#  {'country': 'Asia',
#   'confirmed': 369631,
#   'new_cases': 11447,
#   'deaths': 14369,
#   'recovered': 175956,
#   'active': 179306,
#   'critical': 6398,
#   'new_deaths': 303,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('0'),
# ...

# %% [markdown]
# # Extract data using the country name

# %%
country=covid.get_status_by_country_name('India')
country
# Out:
# {'country': 'India',
#  'confirmed': 15722,
#  'new_cases': 1370,
#  'deaths': 521,
#  'recovered': 2463,
#  'active': 12738,
#  'critical': 0,
#  'new_deaths': 35,
#  'total_tests': 335123,
#  'total_tests_per_million': Decimal('0'),
#  'total_cases_per_million': Decimal('11'),
#  'total_deaths_per_million': Decimal('0.4')}

# %% [markdown]
# # Accessing specific value

# %%
death=country['active']
death
# Out:
# 12738

# %% [markdown]
# # Finding the confirmed cases worlwide

# %%
confirm=covid.get_total_confirmed_cases()
confirm
# Out:
# 2321386
